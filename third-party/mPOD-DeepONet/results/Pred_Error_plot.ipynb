# %%
from display_utils import plot_TE, plot_NS, plot_Eflow, plot_MHD

# %% [markdown]
# ## TE_heat

# %%
# data_name = 'NS_heat'
data_name = 'TE_heat'
# data_name = 'E_flow'
# data_name = 'MHD'
out_channels= 5 if data_name == 'MHD' else 3

data_dict = torch.load(f'pred_all/pred_{data_name}.pt')
data_dict.keys()
# Out:
# dict_keys(['x', 'y_tr', 'FNO', 'CDeepONet(4096)', 'CDeepONet(2048)', 'CDeepONet(1024)', 'CDeepONet(512)', 'CDeepONet(256)', 'MDeepONet(4096)', 'MDeepONet(2048)', 'MDeepONet(1024)', 'MDeepONet(512)', 'MDeepONet(256)', 'CPodONet(4096)', 'CPodONet(2048)', 'CPodONet(1024)', 'CPodONet(512)', 'CPodONet(256)', 'MPodONet(4096)', 'MPodONet(2048)', 'MPodONet(1024)', 'MPodONet(512)', 'MPodONet(256)', 'KPodONet(4096)', 'KPodONet(2048)', 'KPodONet(1024)', 'KPodONet(512)', 'KPodONet(256)'])

# %%
plot_TE(data_dict, ['FNO','CDeepONet(256)', 'MDeepONet(512)','CPodONet(512)', 'MPodONet(2048)', 'KPodONet(256)'], mode='both')

# %% [markdown]
# ## NS_heat

# %%
data_name = 'NS_heat'
# data_name = 'TE_heat'
# data_name = 'E_flow'
# data_name = 'MHD'
out_channels= 5 if data_name == 'MHD' else 3

data_dict = torch.load(f'pred_all/pred_{data_name}.pt')
data_dict.keys()
# Out:
# dict_keys(['x', 'y_tr', 'FNO', 'CDeepONet(4096)', 'CDeepONet(2048)', 'CDeepONet(1024)', 'CDeepONet(512)', 'CDeepONet(256)', 'MDeepONet(4096)', 'MDeepONet(2048)', 'MDeepONet(1024)', 'MDeepONet(512)', 'MDeepONet(256)', 'CPodONet(4096)', 'CPodONet(2048)', 'CPodONet(1024)', 'CPodONet(512)', 'CPodONet(256)', 'MPodONet(4096)', 'MPodONet(2048)', 'MPodONet(1024)', 'MPodONet(512)', 'MPodONet(256)', 'KPodONet(4096)', 'KPodONet(2048)', 'KPodONet(1024)', 'KPodONet(512)', 'KPodONet(256)'])

# %%
plot_NS(data_dict, ['FNO','CDeepONet(2048)', 'MDeepONet(1024)', 'CPodONet(512)',  'MPodONet(1024)', 'KPodONet(512)'], mode='both')

# %% [markdown]
# ## E_flow

# %%
# data_name = 'NS_heat'
# data_name = 'TE_heat'
data_name = 'E_flow'
# data_name = 'MHD'
out_channels= 5 if data_name == 'MHD' else 3

data_dict = torch.load(f'pred_all/pred_{data_name}.pt')
data_dict.keys()
# Out:
# dict_keys(['x', 'y_tr', 'FNO', 'CDeepONet(4096)', 'CDeepONet(2048)', 'CDeepONet(1024)', 'CDeepONet(512)', 'CDeepONet(256)', 'MDeepONet(4096)', 'MDeepONet(2048)', 'MDeepONet(1024)', 'MDeepONet(512)', 'MDeepONet(256)', 'CPodONet(4096)', 'CPodONet(2048)', 'CPodONet(1024)', 'CPodONet(512)', 'CPodONet(256)', 'MPodONet(4096)', 'MPodONet(2048)', 'MPodONet(1024)', 'MPodONet(512)', 'MPodONet(256)', 'KPodONet(4096)', 'KPodONet(2048)', 'KPodONet(1024)', 'KPodONet(512)', 'KPodONet(256)'])

# %%
plot_Eflow(data_dict, ['FNO','CDeepONet(256)', 'MDeepONet(256)','CPodONet(4096)',  'MPodONet(512)', 'KPodONet(2048)'], mode='both')

# %% [markdown]
# ## MHD

# %%
# data_name = 'NS_heat'
# data_name = 'TE_heat'
# data_name = 'E_flow'
data_name = 'MHD'
out_channels= 5 if data_name == 'MHD' else 3

data_dict = torch.load(f'pred_all/pred_{data_name}.pt')
data_dict.keys()
# Out:
# dict_keys(['x', 'y_tr', 'FNO', 'CDeepONet(4096)', 'CDeepONet(2048)', 'CDeepONet(1024)', 'CDeepONet(512)', 'CDeepONet(256)', 'MDeepONet(4096)', 'MDeepONet(2048)', 'MDeepONet(1024)', 'MDeepONet(512)', 'MDeepONet(256)', 'CPodONet(4096)', 'CPodONet(2048)', 'CPodONet(1024)', 'CPodONet(512)', 'CPodONet(256)', 'MPodONet(4096)', 'MPodONet(2048)', 'MPodONet(1024)', 'MPodONet(512)', 'MPodONet(256)', 'KPodONet(4096)', 'KPodONet(2048)', 'KPodONet(1024)', 'KPodONet(512)', 'KPodONet(256)'])

# %%
plot_MHD(data_dict, ['FNO','CDeepONet(2048)', 'MDeepONet(512)','CPodONet(2048)',  'MPodONet(512)', 'KPodONet(512)'], mode='both')
